# %% [markdown]
# # 测试ChatTTS

# %%
import ChatTTS
import torch
import torchaudio

chat = ChatTTS.Chat()
chat.load(compile=False) # Set to True for better performance

texts = ["PUT YOUR 1st TEXT HERE", "PUT YOUR 2nd TEXT HERE"]

wavs = chat.infer(texts)

for i in range(len(wavs)):
    """
    In some versions of torchaudio, the first line works but in other versions, so does the second line.
    """
    try:
        torchaudio.save(f"basic_output{i}.wav", torch.from_numpy(wavs[i]).unsqueeze(0), 24000)
    except:
        torchaudio.save(f"basic_output{i}.wav", torch.from_numpy(wavs[i]), 24000)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File g:\App\Anaconda\envs\learing\lib\shutil.py:618, in _rmtree_unsafe(path, onerror)
#     617 try:
# --> 618     os.unlink(fullname)
#     619 except OSError:
#
# PermissionError: [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'C:\\Users\\23668\\AppData\\Local\\Temp\\tmp2_4ycvmu\\rvcmd.exe'
#
# During handling of the above exception, another exception occurred:
#
# PermissionError                           Traceback (most recent call last)
# File g:\App\Anaconda\envs\learing\lib\tempfile.py:852, in TemporaryDirectory._rmtree.<locals>.onerror(func, path, exc_info)
#     851 try:
# --> 852     _os.unlink(path)
#     853 # PermissionError is raised on FreeBSD for directories
#
# PermissionError: [WinError 32] 另一个程序正在使用此文件，进程无法访问。: 'C:\\Users\\23668\\AppData\\Local\\Temp\\tmp2_4ycvmu\\rvcmd.exe'
#
# During handling of the above exception, another exception occurred:
#
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[3], line 6
#       3 import torchaudio
#       5 chat = ChatTTS.Chat()
# ----> 6 chat.load(compile=False) # Set to True for better performance
#       8 texts = ["PUT YOUR 1st TEXT HERE", "PUT YOUR 2nd TEXT HERE"]
#      10 wavs = chat.infer(texts)
#
# File d:\desktop\寒假项目\chattts_teacher\chattts\ChatTTS\core.py:149, in Chat.load(self, source, force_redownload, compile, custom_path, device, coef, use_flash_attn, use_vllm, experimental)
#     137 def load(
#     138     self,
#     139     source: Literal["huggingface", "local", "custom"] = "local",
#    (...)
#     147     experimental: bool = False,
#     148 ) -> bool:
# --> 149     download_path = self.download_models(source, force_redownload, custom_path)
#     150     if download_path is None:
#     151         return False
#
# File d:\desktop\寒假项目\chattts_teacher\chattts\ChatTTS\core.py:77, in Chat.download_models(self, source, force_redownload, custom_path)
#      72 download_path = custom_path if custom_path is not None else os.getcwd()
#      73 if (
#      74     not check_all_assets(Path(download_path), self.sha256_map, update=True)
#      75     or force_redownload
#      76 ):
# ---> 77     with tempfile.TemporaryDirectory() as tmp:
#      78         download_all_assets(tmpdir=tmp, homedir=download_path)
#      79     if not check_all_assets(
#      80         Path(download_path), self.sha256_map, update=False
#      81     ):
#
# File g:\App\Anaconda\envs\learing\lib\tempfile.py:878, in TemporaryDirectory.__exit__(self, exc, value, tb)
#     877 def __exit__(self, exc, value, tb):
# --> 878     self.cleanup()
#
# File g:\App\Anaconda\envs\learing\lib\tempfile.py:882, in TemporaryDirectory.cleanup(self)
#     880 def cleanup(self):
#     881     if self._finalizer.detach() or _os.path.exists(self.name):
# --> 882         self._rmtree(self.name, ignore_errors=self._ignore_cleanup_errors)
#
# File g:\App\Anaconda\envs\learing\lib\tempfile.py:864, in TemporaryDirectory._rmtree(cls, name, ignore_errors)
#     861         if not ignore_errors:
#     862             raise
# --> 864 _shutil.rmtree(name, onerror=onerror)
#
# File g:\App\Anaconda\envs\learing\lib\shutil.py:750, in rmtree(path, ignore_errors, onerror)
#     748     # can't continue even if onerror hook returns
#     749     return
# --> 750 return _rmtree_unsafe(path, onerror)
#
# File g:\App\Anaconda\envs\learing\lib\shutil.py:620, in _rmtree_unsafe(path, onerror)
#     618             os.unlink(fullname)
#     619         except OSError:
# --> 620             onerror(os.unlink, fullname, sys.exc_info())
#     621 try:
#     622     os.rmdir(path)
#
# File g:\App\Anaconda\envs\learing\lib\tempfile.py:855, in TemporaryDirectory._rmtree.<locals>.onerror(func, path, exc_info)
#     853     # PermissionError is raised on FreeBSD for directories
#     854     except (IsADirectoryError, PermissionError):
# --> 855         cls._rmtree(path, ignore_errors=ignore_errors)
#     856 except FileNotFoundError:
#     857     pass
#
# File g:\App\Anaconda\envs\learing\lib\tempfile.py:864, in TemporaryDirectory._rmtree(cls, name, ignore_errors)
#     861         if not ignore_errors:
#     862             raise
# --> 864 _shutil.rmtree(name, onerror=onerror)
#
# File g:\App\Anaconda\envs\learing\lib\shutil.py:750, in rmtree(path, ignore_errors, onerror)
#     748     # can't continue even if onerror hook returns
#     749     return
# --> 750 return _rmtree_unsafe(path, onerror)
#
# File g:\App\Anaconda\envs\learing\lib\shutil.py:601, in _rmtree_unsafe(path, onerror)
#     599         entries = list(scandir_it)
#     600 except OSError:
# --> 601     onerror(os.scandir, path, sys.exc_info())
#     602     entries = []
#     603 for entry in entries:
#
# File g:\App\Anaconda\envs\learing\lib\shutil.py:598, in _rmtree_unsafe(path, onerror)
#     596 def _rmtree_unsafe(path, onerror):
#     597     try:
# --> 598         with os.scandir(path) as scandir_it:
#     599             entries = list(scandir_it)
#     600     except OSError:
#
# NotADirectoryError: [WinError 267] 目录名称无效。: 'C:\\Users\\23668\\AppData\\Local\\Temp\\tmp2_4ycvmu\\rvcmd.exe'
